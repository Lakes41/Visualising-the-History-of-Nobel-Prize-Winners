# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Start coding here!

# %%
nobel = pd.read_csv('data/nobel.csv')
nobel.head()
# Out:
#    year    category  ... death_city death_country
# 0  1901   Chemistry  ...     Berlin       Germany
# 1  1901  Literature  ...   Châtenay        France
# 2  1901    Medicine  ...    Marburg       Germany
# 3  1901       Peace  ...     Heiden   Switzerland
# 4  1901       Peace  ...      Paris        France
#
# [5 rows x 18 columns]

# %%
gender_value = nobel.value_counts('sex')
print(gender_value.head())
top_gender = 'Male'
# Out:
# sex
# Male      905
# Female     65
# dtype: int64

# %%
country_value = nobel.value_counts('birth_country')
print(country_value.head())
top_country = 'United States of America'
# Out:
# birth_country
# United States of America    291
# United Kingdom               91
# Germany                      67
# France                       58
# Sweden                       30
# dtype: int64

# %%
usa_nobel = nobel[nobel['birth_country'] == 'United States of America']
usa_nobel
# Out:
#      year   category  ...      death_city             death_country
# 35   1906      Peace  ...  Oyster Bay, NY  United States of America
# 72   1912      Peace  ...    New York, NY  United States of America
# 79   1914  Chemistry  ...   Cambridge, MA  United States of America
# 95   1919      Peace  ...  Washington, DC  United States of America
# 117  1923    Physics  ...  San Marino, CA  United States of America
# ..    ...        ...  ...             ...                       ...
# 987  2022  Economics  ...             NaN                       NaN
# 988  2022  Economics  ...             NaN                       NaN
# 990  2023   Medicine  ...             NaN                       NaN
# 995  2023  Chemistry  ...             NaN                       NaN
# 999  2023  Economics  ...             NaN                       NaN
#
# [291 rows x 18 columns]

# %%
nobel['usa_born_winner'] = nobel['birth_country'] == 'United States of America'
nobel['decade'] = (np.floor(nobel['year'] / 10) * 10).astype(int)
prop_usa_winners = nobel.groupby('decade', as_index=False)['usa_born_winner'].sum()
print(nobel['decade'])
prop_usa_winners
# Out:
# 0      1900
# 1      1900
# 2      1900
# 3      1900
# 4      1900
#        ...
# 995    2020
# 996    2020
# 997    2020
# 998    2020
# 999    2020
# Name: decade, Length: 1000, dtype: int64
#     decade  usa_born_winner
# 0     1900                1
# 1     1910                3
# 2     1920                4
# 3     1930               14
# 4     1940               13
# 5     1950               21
# 6     1960               21
# 7     1970               33
# 8     1980               31
# 9     1990               42
# 10    2000               52
# 11    2010               38
# 12    2020               18

# %%
max_decade_usa = prop_usa_winners[prop_usa_winners['usa_born_winner'] == prop_usa_winners['usa_born_winner'].max()]['decade'].values[0]
max_decade_usa
# Out:
# 2000

# %%
nobel['female_laureate'] = nobel['sex'] == 'Female'
prop_female_laureate = nobel.groupby(['decade', 'category'], as_index=False)['female_laureate'].mean()
prop_female_laureate
# Out:
#     decade    category  female_laureate
# 0     1900   Chemistry         0.000000
# 1     1900  Literature         0.100000
# 2     1900    Medicine         0.000000
# 3     1900       Peace         0.071429
# 4     1900     Physics         0.076923
# ..     ...         ...              ...
# 67    2020   Economics         0.111111
# 68    2020  Literature         0.500000
# 69    2020    Medicine         0.125000
# 70    2020       Peace         0.285714
# 71    2020     Physics         0.166667
#
# [72 rows x 3 columns]

# %%
x = prop_female_laureate[prop_female_laureate['female_laureate'] == prop_female_laureate['female_laureate'].max()]
max_female_dict = {x.iloc[0][0] : x.iloc[0][1]}
max_female_dict
# Out:
# {2020: 'Literature'}

# %%
max_female_decade_category = prop_female_laureate[prop_female_laureate['female_laureate'] == prop_female_laureate['female_laureate'].max()][['decade', 'category']]
max_female_dict = {max_female_decade_category['decade'].values[0]: max_female_decade_category['category'].values[0]}

# %%
num_repeaters = nobel['full_name'].value_counts()

# %%
repeaters = num_repeaters[num_repeaters >= 2].index
repeat_list = list(repeaters)
repeat_list
# Out:
# ['Comité international de la Croix Rouge (International Committee of the Red Cross)',
#  'Linus Carl Pauling',
#  'John Bardeen',
#  'Frederick Sanger',
#  'Marie Curie, née Sklodowska',
#  'Office of the United Nations High Commissioner for Refugees (UNHCR)']
